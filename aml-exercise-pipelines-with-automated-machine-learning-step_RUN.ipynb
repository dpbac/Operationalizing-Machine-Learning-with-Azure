# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-132736
# aml-quickstarts-132736
# southcentralus
# 9a7511b8-150f-4a58-8528-3e7d50216c31

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-bike-experiment-1'
project_folder = './pipeline-bike-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-bike-experiment-1,
# Workspace: quick-starts-ws-132736)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bikesharing Dataset"
description_text = "Bike Sharing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://raw.githubusercontent.com/Azure/MachineLearningNotebooks/master/how-to-use-azureml/automated-machine-learning/forecasting-bike-share/bike-no.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#           instant      season          yr        mnth     weekday  weathersit  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    2.997264    1.395349
# std    211.165812    1.110807    0.500342    3.451913    2.004787    0.544894
# min      1.000000    1.000000    0.000000    1.000000    0.000000    1.000000
# 25%    183.500000    2.000000    0.000000    4.000000    1.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    3.000000    1.000000
# 75%    548.500000    3.000000    1.000000   10.000000    5.000000    2.000000
# max    731.000000    4.000000    1.000000   12.000000    6.000000    3.000000
#
#              temp       atemp         hum   windspeed       casual  \
# count  731.000000  731.000000  731.000000  731.000000   731.000000
# mean     0.495385    0.474354    0.627894    0.190486   848.176471
# std      0.183051    0.162961    0.142429    0.077498   686.622488
# min      0.059130    0.079070    0.000000    0.022392     2.000000
# 25%      0.337083    0.337842    0.520000    0.134950   315.500000
# 50%      0.498333    0.486733    0.626667    0.180975   713.000000
# 75%      0.655417    0.608602    0.730209    0.233214  1096.000000
# max      0.861667    0.840896    0.972500    0.507463  3410.000000
#
#         registered          cnt
# count   731.000000   731.000000
# mean   3656.172367  4504.348837
# std    1560.256377  1937.211452
# min      20.000000    22.000000
# 25%    2497.000000  3152.000000
# 50%    3662.000000  4548.000000
# 75%    4776.500000  5956.000000
# max    6946.000000  8714.000000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    instant       date  season  yr  mnth  weekday  weathersit      temp  \
# 0        1 2011-01-01       1   0     1        6           2  0.344167
# 1        2 2011-01-02       1   0     1        0           2  0.363478
# 2        3 2011-01-03       1   0     1        1           1  0.196364
# 3        4 2011-01-04       1   0     1        2           1  0.200000
# 4        5 2011-01-05       1   0     1        3           1  0.226957
#
#       atemp       hum  windspeed  casual  registered   cnt
# 0  0.363625  0.805833   0.160446     331         654   985
# 1  0.353739  0.696087   0.248539     131         670   801
# 2  0.189405  0.437273   0.248309     120        1229  1349
# 3  0.212122  0.590435   0.160296     108        1454  1562
# 4  0.229270  0.436957   0.186900      82        1518  1600

# %%
df.head()
# Out:
#    instant       date  season  yr  mnth  weekday  weathersit      temp  \
# 0        1 2011-01-01       1   0     1        6           2  0.344167
# 1        2 2011-01-02       1   0     1        0           2  0.363478
# 2        3 2011-01-03       1   0     1        1           1  0.196364
# 3        4 2011-01-04       1   0     1        2           1  0.200000
# 4        5 2011-01-05       1   0     1        3           1  0.226957
#
#       atemp       hum  windspeed  casual  registered   cnt
# 0  0.363625  0.805833   0.160446     331         654   985
# 1  0.353739  0.696087   0.248539     131         670   801
# 2  0.189405  0.437273   0.248309     120        1229  1349
# 3  0.212122  0.590435   0.160296     108        1454  1562
# 4  0.229270  0.436957   0.186900      82        1518  1600

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `time_column_name` has to be `cnt` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'normalized_root_mean_squared_error',
    "n_cross_validations": 5
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "forecasting",
                             training_data=dataset,
                             time_column_name="date", 
                             label_column_name="cnt",  
                             path = project_folder,
                             enable_early_stopping= True,
                             #featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [c09bb513][14cc97c8-469d-437e-982a-ef5c7594cb22], (This step will run and generate new outputs)
# Submitted PipelineRun 93ffb7cb-002a-433c-93c4-d0e9890acc9b
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-bike-experiment-1/runs/93ffb7cb-002a-433c-93c4-d0e9890acc9b?wsid=/subscriptions/9a7511b8-150f-4a58-8528-3e7d50216c31/resourcegroups/aml-quickstarts-132736/workspaces/quick-starts-ws-132736

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 93ffb7cb-002a-433c-93c4-d0e9890acc9b
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-bike-experiment-1/runs/93ffb7cb-002a-433c-93c4-d0e9890acc9b?wsid=/subscriptions/9a7511b8-150f-4a58-8528-3e7d50216c31/resourcegroups/aml-quickstarts-132736/workspaces/quick-starts-ws-132736
# PipelineRun Status: Running
# WARNING:azureml.pipeline.core.run:Expected a StepRun object but received <class 'azureml.core.run.Run'> instead.
# This usually indicates a package conflict with one of the dependencies of azureml-core or azureml-pipeline-core.
# Please check for package conflicts in your python environment
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '93ffb7cb-002a-433c-93c4-d0e9890acc9b', 'status': 'Completed', 'startTimeUtc': '2021-01-01T09:49:26.459951Z', 'endTimeUtc': '2021-01-01T10:25:27.87427Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg132736.blob.core.windows.net/azureml/ExperimentRun/dcid.93ffb7cb-002a-433c-93c4-d0e9890acc9b/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=5oPxwl4wlTZ1XR7c4Ta2ZZqhNP9aKizdLBnugQYyFVs%3D&st=2021-01-01T09%3A39%3A34Z&se=2021-01-01T17%3A49%3A34Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg132736.blob.core.windows.net/azureml/ExperimentRun/dcid.93ffb7cb-002a-433c-93c4-d0e9890acc9b/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=G%2F5Ye%2FL2XLRhTUAKTageYUtpIXnXBIspGP948LX06Ro%3D&st=2021-01-01T09%3A39%3A34Z&se=2021-01-01T17%3A49%3A34Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg132736.blob.core.windows.net/azureml/ExperimentRun/dcid.93ffb7cb-002a-433c-93c4-d0e9890acc9b/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=KhpOfU%2FVSpnweYPw3SoPNKnjtu3qYwHtkOuLULH9urw%3D&st=2021-01-01T09%3A39%3A34Z&se=2021-01-01T17%3A49%3A34Z&sp=r'}}
# 'Finished'

# %%
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/a74d40f0-2b1c-4723-9cff-6f1d798a4fd2/metrics_data
# Downloaded azureml/a74d40f0-2b1c-4723-9cff-6f1d798a4fd2/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_1  \
# normalized_root_mean_squared_error                    [3.586522034137506e-05]
# median_absolute_error                                     [0.311740495207232]
# root_mean_squared_log_error                          [0.00012116031541129502]
# normalized_mean_absolute_error                        [3.586522034137506e-05]
# normalized_root_mean_squared_log_error               [2.0406612067675017e-05]
# r2_score                                                                [0.0]
# root_mean_squared_error                                   [0.311740495207232]
# explained_variance                                                      [1.0]
# spearman_correlation                                                   [-1.0]
# mean_absolute_percentage_error                          [0.01212326867238746]
# normalized_median_absolute_error                      [3.586522034137506e-05]
# mean_absolute_error                                       [0.311740495207232]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_24  \
# normalized_root_mean_squared_error                        [0.0222609315240132]
# median_absolute_error                                     [193.49201680672272]
# root_mean_squared_log_error                               [0.0950567840653667]
# normalized_mean_absolute_error                            [0.0222609315240132]
# normalized_root_mean_squared_log_error                  [0.016010084739692388]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [193.49201680672272]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                             [9.831553732412608]
# normalized_median_absolute_error                          [0.0222609315240132]
# mean_absolute_error                                       [193.49201680672272]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_37  \
# normalized_root_mean_squared_error                     [0.0002724052745003718]
# median_absolute_error                                     [2.3677466459572316]
# root_mean_squared_log_error                            [0.0009072075208127472]
# normalized_mean_absolute_error                         [0.0002724052745003718]
# normalized_root_mean_squared_log_error                [0.00015279781898270867]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [2.3677466459572316]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                           [0.09090126285472615]
# normalized_median_absolute_error                       [0.0002724052745003718]
# mean_absolute_error                                       [2.3677466459572316]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_40  \
# normalized_root_mean_squared_error                    [0.00014740399589849615]
# median_absolute_error                                     [1.2812355323497286]
# root_mean_squared_log_error                            [0.0006827411746728629]
# normalized_mean_absolute_error                        [0.00014740399589849615]
# normalized_root_mean_squared_log_error                [0.00011499173014598333]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [1.2812355323497286]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                            [0.0683440390113941]
# normalized_median_absolute_error                      [0.00014740399589849615]
# mean_absolute_error                                       [1.2812355323497286]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_33  \
# normalized_root_mean_squared_error                    [0.00010647384107460038]
# median_absolute_error                                     [0.9254706266204267]
# root_mean_squared_log_error                           [0.00038413995973787254]
# normalized_mean_absolute_error                        [0.00010647384107460038]
# normalized_root_mean_squared_log_error                 [6.469936225778665e-05]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [0.9254706266204267]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                          [0.038432998016989905]
# normalized_median_absolute_error                      [0.00010647384107460038]
# mean_absolute_error                                       [0.9254706266204267]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_21  \
# normalized_root_mean_squared_error                       [0.02708323416384919]
# median_absolute_error                                     [235.40747135217717]
# root_mean_squared_log_error                               [0.1132818823362582]
# normalized_mean_absolute_error                           [0.02708323416384919]
# normalized_root_mean_squared_log_error                  [0.019079674885994255]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [235.40747135217717]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                             [11.93317143215101]
# normalized_median_absolute_error                         [0.02708323416384919]
# mean_absolute_error                                       [235.40747135217717]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_41  \
# normalized_root_mean_squared_error                      [1.54098049590524e-07]
# median_absolute_error                                  [0.0013394202470408344]
# root_mean_squared_log_error                            [7.149066025391449e-07]
# normalized_mean_absolute_error                          [1.54098049590524e-07]
# normalized_root_mean_squared_log_error                [1.2040924169858868e-07]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                [0.0013394202470408344]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                         [7.153195309902809e-05]
# normalized_median_absolute_error                        [1.54098049590524e-07]
# mean_absolute_error                                    [0.0013394202470408344]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_0  \
# normalized_root_mean_squared_error                      [0.07953388438319364]
# median_absolute_error                                     [691.3085230587192]
# root_mean_squared_log_error                             [0.31186772705979476]
# normalized_mean_absolute_error                          [0.07953388438319364]
# normalized_root_mean_squared_log_error                 [0.052526800552910216]
# r2_score                                                                [0.0]
# root_mean_squared_error                                   [691.3085230587192]
# explained_variance                                                      [1.0]
# spearman_correlation                                                   [-1.0]
# mean_absolute_percentage_error                           [40.801756035280256]
# normalized_median_absolute_error                        [0.07953388438319364]
# mean_absolute_error                                       [691.3085230587192]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_27  \
# normalized_root_mean_squared_error                      [0.020448054760539534]
# median_absolute_error                                     [177.73449197860964]
# root_mean_squared_log_error                              [0.09654019082288165]
# normalized_mean_absolute_error                          [0.020448054760539534]
# normalized_root_mean_squared_log_error                  [0.016259929799408643]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [177.73449197860964]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                              [9.00097894365501]
# normalized_median_absolute_error                        [0.020448054760539534]
# mean_absolute_error                                       [177.73449197860964]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_20  \
# normalized_root_mean_squared_error                      [0.026783673105838096]
# median_absolute_error                                     [232.80368663594473]
# root_mean_squared_log_error                              [0.10123651218671252]
# normalized_mean_absolute_error                          [0.026783673105838096]
# normalized_root_mean_squared_log_error                  [0.017050914932548174]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [232.80368663594473]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                            [10.177552128158805]
# normalized_median_absolute_error                        [0.026783673105838096]
# mean_absolute_error                                       [232.80368663594473]
#
#                                         ...  \
# normalized_root_mean_squared_error      ...
# median_absolute_error                   ...
# root_mean_squared_log_error             ...
# normalized_mean_absolute_error          ...
# normalized_root_mean_squared_log_error  ...
# r2_score                                ...
# root_mean_squared_error                 ...
# explained_variance                      ...
# spearman_correlation                    ...
# mean_absolute_percentage_error          ...
# normalized_median_absolute_error        ...
# mean_absolute_error                     ...
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_28  \
# normalized_root_mean_squared_error                       [0.01685004466581847]
# median_absolute_error                                     [146.46058823529415]
# root_mean_squared_log_error                              [0.06584018763136737]
# normalized_mean_absolute_error                           [0.01685004466581847]
# normalized_root_mean_squared_log_error                  [0.011089234646635755]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [146.46058823529415]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                             [6.578864198030724]
# normalized_median_absolute_error                         [0.01685004466581847]
# mean_absolute_error                                       [146.46058823529415]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_15  \
# normalized_root_mean_squared_error                       [0.02233435541281518]
# median_absolute_error                                     [194.13021724818958]
# root_mean_squared_log_error                              [0.08113129445075362]
# normalized_mean_absolute_error                           [0.02233435541281518]
# normalized_root_mean_squared_log_error                   [0.01366466277992622]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [194.13021724818958]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                             [8.024240915032127]
# normalized_median_absolute_error                         [0.02233435541281518]
# mean_absolute_error                                       [194.13021724818958]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_12  \
# normalized_root_mean_squared_error                      [0.007148386182616437]
# median_absolute_error                                     [62.133772699302064]
# root_mean_squared_log_error                              [0.03452643582075563]
# normalized_mean_absolute_error                          [0.007148386182616437]
# normalized_root_mean_squared_log_error                 [0.0058151679407724335]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [62.133772699302064]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                             [3.564399013075408]
# normalized_median_absolute_error                        [0.007148386182616437]
# mean_absolute_error                                       [62.133772699302064]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_3  \
# normalized_root_mean_squared_error                       [0.1097100782328578]
# median_absolute_error                                                 [953.6]
# root_mean_squared_log_error                             [0.43670407984373905]
# normalized_mean_absolute_error                           [0.1097100782328578]
# normalized_root_mean_squared_log_error                  [0.07355255485668191]
# r2_score                                                                [0.0]
# root_mean_squared_error                                               [953.6]
# explained_variance                                                      [1.0]
# spearman_correlation                                                   [-1.0]
# mean_absolute_percentage_error                            [41.90871839259893]
# normalized_median_absolute_error                         [0.1097100782328578]
# mean_absolute_error                                                   [953.6]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_8  \
# normalized_root_mean_squared_error                   [4.2470706345303317e-07]
# median_absolute_error                                  [0.003691553795533764]
# root_mean_squared_log_error                          [1.9691822686240814e-06]
# normalized_mean_absolute_error                       [4.2470706345303317e-07]
# normalized_root_mean_squared_log_error                [3.316625456936514e-07]
# r2_score                                                                [0.0]
# root_mean_squared_error                                [0.003691553795533764]
# explained_variance                                                      [1.0]
# spearman_correlation                                                   [-1.0]
# mean_absolute_percentage_error                       [0.00019703208376969312]
# normalized_median_absolute_error                     [4.2470706345303317e-07]
# mean_absolute_error                                    [0.003691553795533764]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_31  \
# normalized_root_mean_squared_error                    [0.00026260011750575565]
# median_absolute_error                                      [2.282520221360028]
# root_mean_squared_log_error                            [0.0014572031784441108]
# normalized_mean_absolute_error                        [0.00026260011750575565]
# normalized_root_mean_squared_log_error                [0.00024543168169666077]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                    [2.282520221360028]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                           [0.14609495503384626]
# normalized_median_absolute_error                      [0.00026260011750575565]
# mean_absolute_error                                        [2.282520221360028]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_39  \
# normalized_root_mean_squared_error                       [0.02466239547259543]
# median_absolute_error                                     [214.36554144779947]
# root_mean_squared_log_error                              [0.09488102190426276]
# normalized_mean_absolute_error                           [0.02466239547259543]
# normalized_root_mean_squared_log_error                  [0.015980481727966567]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [214.36554144779947]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                             [9.150573008046418]
# normalized_median_absolute_error                         [0.02466239547259543]
# mean_absolute_error                                       [214.36554144779947]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_44  \
# normalized_root_mean_squared_error                    [1.5409804953820608e-07]
# median_absolute_error                                   [0.001339420246586087]
# root_mean_squared_log_error                            [7.149066021838734e-07]
# normalized_mean_absolute_error                        [1.5409804953820608e-07]
# normalized_root_mean_squared_log_error                [1.2040924163875155e-07]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                 [0.001339420246586087]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                         [7.153195307401793e-05]
# normalized_median_absolute_error                      [1.5409804953820608e-07]
# mean_absolute_error                                     [0.001339420246586087]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_19  \
# normalized_root_mean_squared_error                      [0.024188663249259876]
# median_absolute_error                                     [210.24786096256685]
# root_mean_squared_log_error                              [0.10317703711885215]
# normalized_mean_absolute_error                          [0.024188663249259876]
# normalized_root_mean_squared_log_error                   [0.01737775082236407]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [210.24786096256685]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                            [10.764507193205713]
# normalized_median_absolute_error                        [0.024188663249259876]
# mean_absolute_error                                       [210.24786096256685]
#
#                                        a74d40f0-2b1c-4723-9cff-6f1d798a4fd2_17
# normalized_root_mean_squared_error                       [0.01963066417909952]
# median_absolute_error                                     [170.62973304473303]
# root_mean_squared_log_error                              [0.08399231127374698]
# normalized_mean_absolute_error                           [0.01963066417909952]
# normalized_root_mean_squared_log_error                  [0.014146533929136474]
# r2_score                                                                 [0.0]
# root_mean_squared_error                                   [170.62973304473303]
# explained_variance                                                       [1.0]
# spearman_correlation                                                    [-1.0]
# mean_absolute_percentage_error                             [8.729712077960773]
# normalized_median_absolute_error                         [0.01963066417909952]
# mean_absolute_error                                       [170.62973304473303]
#
# [12 rows x 42 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/a74d40f0-2b1c-4723-9cff-6f1d798a4fd2/model_data
# Downloaded azureml/a74d40f0-2b1c-4723-9cff-6f1d798a4fd2/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# ForecastingPipelineWrapper(pipeline=Pipeline(memory=None,
#                                              steps=[('timeseriestransformer',
#                                                      TimeSeriesTransformer(featurization_config=None,
#                                                                            pipeline_type=<TimeSeriesPipelineType.FULL: 1>)),
#                                                     ('StandardScalerWrapper',
#                                                      <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper object at 0x7f1be6a27710>),
#                                                     ('LassoLars',
#                                                      LassoLars(alpha=0.001,
#                                                                copy_X=True,
#                                                                eps=2.220446049250313e-16,
#                                                                fit_intercept=True,
#                                                                fit_path=True,
#                                                                max_iter=500,
#                                                                normalize=False,
#                                                                positive=False,
#                                                                precompute='auto',
#                                                                verbose=False))],
#                                              verbose=False),
#                            stddev=None)

# %%
best_model.steps
# Out:
# [('timeseriestransformer',
#   TimeSeriesTransformer(featurization_config=None,
#                         pipeline_type=<TimeSeriesPipelineType.FULL: 1>)),
#  ('StandardScalerWrapper',
#   <azureml.automl.runtime.shared.model_wrappers.StandardScalerWrapper at 0x7f1be6a27710>),
#  ('LassoLars',
#   LassoLars(alpha=0.001, copy_X=True, eps=2.220446049250313e-16,
#             fit_intercept=True, fit_path=True, max_iter=500, normalize=False,
#             positive=False, precompute='auto', verbose=False))]

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bikesharing Train", description="Training bikesharing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bikesharing Train,
# Id: 1fb602d3-a58f-481c-8a71-b3511dff2e4c,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/9a7511b8-150f-4a58-8528-3e7d50216c31/resourceGroups/aml-quickstarts-132736/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-132736/PipelineRuns/PipelineSubmit/1fb602d3-a58f-481c-8a71-b3511dff2e4c)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-bike-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  ace97c95-9514-4c3b-ab91-747f04749095

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-bike-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
